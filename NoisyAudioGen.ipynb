# %% [markdown]
# Noisy Audio Gen
# ===========================
#
# This was the next step after the VAE Output Transformer. With that having run, I now have samples of VAE + NSynth audio data. I will use this same pipeline for training and validating the final model. This, as part of that pipeline creates new audio samples mixing the VAE generated audio with noise.

# %%
# !pip install pandas soundfile numpy librosa
import glob
import os
import sys
import stat
import json
import librosa as lr
import soundfile as sf
import numpy as np
import pandas as pd
from IPython.display import Audio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/karagon/.local/lib/python3.10/site-packages (1.4.2)
# Requirement already satisfied: soundfile in /home/karagon/.local/lib/python3.10/site-packages (0.10.3.post1)
# Requirement already satisfied: numpy in /home/karagon/.local/lib/python3.10/site-packages (1.22.4)
# Requirement already satisfied: librosa in /home/karagon/.local/lib/python3.10/site-packages (0.9.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/lib/python3/dist-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: cffi>=1.0 in /home/karagon/.local/lib/python3.10/site-packages (from soundfile) (1.15.0)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from librosa) (21.3)
# Requirement already satisfied: scipy>=1.2.0 in /usr/lib/python3/dist-packages (from librosa) (1.8.0)
# Requirement already satisfied: joblib>=0.14 in /home/karagon/.local/lib/python3.10/site-packages (from librosa) (1.1.0)
# Requirement already satisfied: pooch>=1.0 in /home/karagon/.local/lib/python3.10/site-packages (from librosa) (1.6.0)
# Requirement already satisfied: decorator>=4.0.10 in /usr/lib/python3/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: scikit-learn>=0.19.1 in /home/karagon/.local/lib/python3.10/site-packages (from librosa) (1.1.1)
# Requirement already satisfied: numba>=0.45.1 in /home/karagon/.local/lib/python3.10/site-packages (from librosa) (0.55.2)
# Requirement already satisfied: resampy>=0.2.2 in /home/karagon/.local/lib/python3.10/site-packages (from librosa) (0.2.2)
# Requirement already satisfied: audioread>=2.1.5 in /home/karagon/.local/lib/python3.10/site-packages (from librosa) (2.1.9)
# Requirement already satisfied: pycparser in /home/karagon/.local/lib/python3.10/site-packages (from cffi>=1.0->soundfile) (2.21)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /home/karagon/.local/lib/python3.10/site-packages (from numba>=0.45.1->librosa) (0.38.1)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from numba>=0.45.1->librosa) (59.6.0)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/lib/python3/dist-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/lib/python3/dist-packages (from pooch>=1.0->librosa) (2.25.1)
# Requirement already satisfied: six>=1.3 in /usr/lib/python3/dist-packages (from resampy>=0.2.2->librosa) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/karagon/.local/lib/python3.10/site-packages (from scikit-learn>=0.19.1->librosa) (3.1.0)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# we need an index of the class labels
class_labels = pd.read_csv('data/audioset/class_labels_indices.csv', index_col=0)
class_labels = class_labels.set_index('mid').to_dict()['display_name']

audioset = pd.read_csv('data/audioset/balanced_train_segments.csv')
def named_labels(labels):
    return set(class_labels[s.strip()] for s in labels.split(','))
    
audioset['length'] = audioset['end_seconds'] - audioset['start_seconds']
audioset['labels'] = audioset['positive_labels'].apply(named_labels)
audioset.drop(labels=['positive_labels'], axis=1, inplace=True)
audioset
# Out:
#               YTID  start_seconds  end_seconds  length  \
# 0      --PJHxphWEs           30.0         40.0    10.0
# 1      --ZhevVpy1s           50.0         60.0    10.0
# 2      --aE2O5G5WE            0.0         10.0    10.0
# 3      --aO5cdqSAg           30.0         40.0    10.0
# 4      --aaILOrkII          200.0        210.0    10.0
# ...            ...            ...          ...     ...
# 22155  zyqg4pYEioQ           20.0         30.0    10.0
# 22156  zz0ddNfz0h0           30.0         40.0    10.0
# 22157  zz8TGV83nkE           80.0         90.0    10.0
# 22158  zzlK8KDqlr0          370.0        380.0    10.0
# 22159  zzya4dDVRLk           30.0         40.0    10.0
#
#                                                   labels
# 0                                         {Gush, Speech}
# 1                                           {Toothbrush}
# 2                                  {Music, Speech, Goat}
# 3                          {Male singing, Child singing}
# 4                            {Gunshot, gunfire, Cap gun}
# ...                                                  ...
# 22155                           {Speech, Sewing machine}
# 22156  {Car, Motor vehicle (road), Ice cream truck, i...
# 22157  {Engine, Motorcycle, Motor vehicle (road), Veh...
# 22158  {Computer keyboard, Clicking, Inside, small ro...
# 22159                            {Sine wave, Chirp tone}
#
# [22160 rows x 5 columns]

# %% [markdown]
# # Pick out noise
#
# I looked at the AudioSet website for types of Noise:
# https://research.google.com/audioset/ontology/noise_1.html
#
# And decided the ones of interest are Hubbub, speech noise, speech babble and White Noise. So now we're going to filter the audioset data to only these

# %%
def is_noise(labels):
    return 'Hubbub, speech noise, speech babble' in labels or 'White noise' in labels or 'Vibration' in labels

audioset = audioset[audioset['labels'].apply(is_noise)]
len(audioset)
# Out:
# 177

# %%
# This reduces the dataset to only 177 items
audioset
# Out:
#               YTID  start_seconds  end_seconds  length  \
# 121    -ETSfElMyNc          220.0        230.0    10.0
# 293    -dEOa2GkXHw           30.0         40.0    10.0
# 611    0MJPqGKIbZg           20.0         30.0    10.0
# 617    0NSzeHaja5o           30.0         40.0    10.0
# 779    0fm0oU8FO0U           30.0         40.0    10.0
# ...            ...            ...          ...     ...
# 21413  xXjmPTooKvs           30.0         40.0    10.0
# 21664  yMdOxfnxkB0           10.0         20.0    10.0
# 21773  yiSeCcyJuxE           10.0         20.0    10.0
# 21915  zIM4eLqtczE            0.0         10.0    10.0
# 22063  zhQGK0mnHPQ          280.0        290.0    10.0
#
#                                                   labels
# 121                                        {White noise}
# 293                                {Speech, White noise}
# 611    {Outside, rural or natural, Speech, Hubbub, sp...
# 617    {Speech, Chatter, Hubbub, speech noise, speech...
# 779                   {Helicopter, Vehicle, White noise}
# ...                                                  ...
# 21413  {Vehicle, Engine, Engine starting, Motor vehic...
# 21664  {Music, Outside, urban or manmade, Speech, Hub...
# 21773                               {Music, White noise}
# 21915      {Speech, Hubbub, speech noise, speech babble}
# 22063                                      {White noise}
#
# [177 rows x 5 columns]

# %%
# we're going to need a youtube downloader to grab the samples. At only 177, I think I won't get banned.
# But I'll use a VPN just to be sure
os.makedirs('tools', exist_ok=True)

# I'm running linux so I can just use the curl command
if not os.path.exists('tools/youtube-dl'):
    # !curl -L https://yt-dl.org/downloads/latest/youtube-dl -o tools/youtube-dl

# Now we'll get to downloading the data
os.makedirs('data/audioset/audio', exist_ok=True)
filenames = []
for i, row in audioset.iterrows():
    audio_filename = f'data/audioset/audio/{row["YTID"]}.wav'
    
    # if we already have the file - skip
    if os.path.exists(audio_filename):
        filenames.append(audio_filename)
        continue
        
    full_audio_filename = f'data/audioset/audio/{row["YTID"]}-full.aac'
    if not os.path.exists(full_audio_filename):
        print(f'Downloading {row["YTID"]}...')
        download_url = f'https://youtube.com/watch?v={row["YTID"]}'
        self_exec = sys.executable
        !"{self_exec}" tools/youtube-dl "{download_url}" --quiet --no-playlist --extract-audio --audio-format aac --output "{full_audio_filename}"
        print(f'   - Done')
 
    # !ffmpeg -loglevel fatal -i "{full_audio_filename}" -ar 16000 -ss "{row['start_seconds']}" -to "{row['end_seconds']}" "{audio_filename}"
    filenames.append(audio_filename)
# Out:
# Downloading 19v5EvjdToU...
# ERROR: Private video
# Sign in if you've been granted access to this video
#    - Done
# Downloading 1XKKLkqdZ34...
#    - Done
# Downloading 2VwH-n3jjL0...
#    - Done
# Downloading 2rPv0UjHwR4...
# ERROR: Video unavailable
#    - Done
# Downloading 3KWSsnZSrq8...
# ERROR: Video unavailable
#    - Done
# Downloading 4kPu2QmfKaQ...
# ERROR: Private video
# Sign in if you've been granted access to this video
#    - Done
# Downloading 6hb0PdtXhvA...
# ERROR: Video unavailable
# This video is no longer available due to a copyright claim by 株式会社バップ
#    - Done
# Downloading 9PyWiDtI0dw...
# ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
#    - Done
# Downloading Fb1Gm9IfOe4...
# ERROR: Video unavailable
#    - Done
# Downloading Jlh_dAyVBf4...
# ERROR: Private video
# Sign in if you've been granted access to this video
#    - Done
# Downloading KRGULadmD0A...
# WARNING: unable to download video info webpage: HTTP Error 410: Gone
# ERROR: Sign in to confirm your age
# This video may be inappropriate for some users.
#    - Done
# Downloading LiehcxCYdIo...
#    - Done
# Downloading UiZpNJKHREs...
# ERROR: Video unavailable
#    - Done
# Downloading VA9sY3fKPew...
# ERROR: Video unavailable
#    - Done
# Downloading YZVRuSPq67M...
# ERROR: Video unavailable
#    - Done
# Downloading bHMhGA4VhQ8...
# ERROR: Video unavailable
# This video contains content from KBS Media, who has blocked it on copyright grounds
#    - Done
# Downloading bbZ9D87RFIM...
#    - Done
# Downloading c6unjZpqSuo...
# ERROR: Video unavailable
#    - Done
# Downloading chB9TzdxxGk...
# ERROR: Video unavailable
#    - Done
# Downloading cyi2WhHtCDw...
#    - Done
# Downloading dPqJgWpoOmk...
# ERROR: This video has been removed for violating YouTube's policy on violent or graphic content
#    - Done
# Downloading k9k0uIya9CQ...
# ERROR: Private video
# Sign in if you've been granted access to this video
#    - Done
# Downloading mKygFOtbUDI...
#    - Done
# Downloading oW7RaV91N8Q...
# ERROR: This video has been removed for violating YouTube's Community Guidelines
#    - Done
# Downloading ov0Fe829K7s...
# ERROR: Private video
# Sign in if you've been granted access to this video
#    - Done
# Downloading ozeQfOdapIU...
#    - Done
# Downloading rUNcwZQSvwY...
# ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
#    - Done
# Downloading sckl7bvI0Uc...
# WARNING: unable to download video info webpage: HTTP Error 410: Gone
# ERROR: Sign in to confirm your age
# This video may be inappropriate for some users.
#    - Done
# Downloading uRIzEtwt8MY...
# WARNING: unable to download video info webpage: HTTP Error 410: Gone
# ERROR: Sign in to confirm your age
# This video may be inappropriate for some users.
#    - Done
# Downloading yiSeCcyJuxE...
# ERROR: Private video
# Sign in if you've been granted access to this video
#    - Done

# %%
audioset = audioset.copy()
audioset['filename'] = filenames
audioset
# Out:
#               YTID  start_seconds  end_seconds  length  \
# 121    -ETSfElMyNc          220.0        230.0    10.0
# 293    -dEOa2GkXHw           30.0         40.0    10.0
# 611    0MJPqGKIbZg           20.0         30.0    10.0
# 617    0NSzeHaja5o           30.0         40.0    10.0
# 779    0fm0oU8FO0U           30.0         40.0    10.0
# ...            ...            ...          ...     ...
# 21413  xXjmPTooKvs           30.0         40.0    10.0
# 21664  yMdOxfnxkB0           10.0         20.0    10.0
# 21773  yiSeCcyJuxE           10.0         20.0    10.0
# 21915  zIM4eLqtczE            0.0         10.0    10.0
# 22063  zhQGK0mnHPQ          280.0        290.0    10.0
#
#                                                   labels  \
# 121                                        {White noise}
# 293                                {Speech, White noise}
# 611    {Outside, rural or natural, Speech, Hubbub, sp...
# 617    {Speech, Chatter, Hubbub, speech noise, speech...
# 779                   {Helicopter, Vehicle, White noise}
# ...                                                  ...
# 21413  {Vehicle, Engine, Engine starting, Motor vehic...
# 21664  {Music, Outside, urban or manmade, Speech, Hub...
# 21773                               {Music, White noise}
# 21915      {Speech, Hubbub, speech noise, speech babble}
# 22063                                      {White noise}
#
#                                   filename
# 121    data/audioset/audio/-ETSfElMyNc.wav
# 293    data/audioset/audio/-dEOa2GkXHw.wav
# 611    data/audioset/audio/0MJPqGKIbZg.wav
# 617    data/audioset/audio/0NSzeHaja5o.wav
# 779    data/audioset/audio/0fm0oU8FO0U.wav
# ...                                    ...
# 21413  data/audioset/audio/xXjmPTooKvs.wav
# 21664  data/audioset/audio/yMdOxfnxkB0.wav
# 21773  data/audioset/audio/yiSeCcyJuxE.wav
# 21915  data/audioset/audio/zIM4eLqtczE.wav
# 22063  data/audioset/audio/zhQGK0mnHPQ.wav
#
# [177 rows x 6 columns]
